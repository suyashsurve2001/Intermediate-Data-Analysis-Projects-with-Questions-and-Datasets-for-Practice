# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/content/sample_data/weather.csv")
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# 1.shows number of unique values

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# 2.shows total number null values

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# 3.FIND all the unique Wind Speed values in data

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# 5.Find the number of times when the 'Weather is exactly clear'(3 methods:value count ,filtering ,group by)

# %%
# value count methods
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# filtering methods
df[df.Weather =='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# group by methods
df.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# 6.FInd the number of times when the windspeed was exactly 4km/h

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df[df['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# 7.Rename the column name 'Weather' of the dataframe to 'Weather condition'

# %%
df.rename(columns={'Weather':'Weather_Condition'},inplace=True)
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# 8.What is the mean Visiblity

# %%
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# 9.What is std deviation of "pressure" in this data

# %%
df['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# 10.What is the variance of "Relavtive Humidity"

# %%
df['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
df.rename(columns={'Rel Hum_%':'Relavtive_Humidity'},inplace =True)

# %%
df.Relavtive_Humidity.var()
# Out:
# 286.24855019850196

# %% [markdown]
# 11.FInd all instance when snow was recordded (3 methods:value count ,filtering ,str.contains)

# %%
df['Weather_Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df.Weather_Condition=='Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 55       1/3/2012 7:00   -14.0             -19.5                  63
# 84      1/4/2012 12:00   -13.7             -21.7                  51
# 86      1/4/2012 14:00   -11.3             -19.0                  53
# 87      1/4/2012 15:00   -10.2             -16.3                  61
# 88      1/4/2012 16:00    -9.4             -15.5                  61
# ...                ...     ...               ...                 ...
# 8779  12/31/2012 19:00     0.1              -2.7                  81
# 8780  12/31/2012 20:00     0.2              -2.4                  83
# 8781  12/31/2012 21:00    -0.5              -1.5                  93
# 8782  12/31/2012 22:00    -0.2              -1.8                  89
# 8783  12/31/2012 23:00     0.0              -2.1                  86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 55                 19           25.0     100.95              Snow
# ...

# %%
df.groupby('Weather_Condition').get_group('Snow')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 55       1/3/2012 7:00   -14.0             -19.5                  63
# 84      1/4/2012 12:00   -13.7             -21.7                  51
# 86      1/4/2012 14:00   -11.3             -19.0                  53
# 87      1/4/2012 15:00   -10.2             -16.3                  61
# 88      1/4/2012 16:00    -9.4             -15.5                  61
# ...                ...     ...               ...                 ...
# 8779  12/31/2012 19:00     0.1              -2.7                  81
# 8780  12/31/2012 20:00     0.2              -2.4                  83
# 8781  12/31/2012 21:00    -0.5              -1.5                  93
# 8782  12/31/2012 22:00    -0.2              -1.8                  89
# 8783  12/31/2012 23:00     0.0              -2.1                  86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 55                 19           25.0     100.95              Snow
# ...

# %% [markdown]
# 12.Find all instances when 'Wind Speed is above 24' and visiblity us '25'

# %%
df[(df['Wind Speed_km/h'] >24)&(df['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 23      1/1/2012 23:00     5.3               2.0                  79
# 24       1/2/2012 0:00     5.2               1.5                  77
# 25       1/2/2012 1:00     4.6               0.0                  72
# 26       1/2/2012 2:00     3.9              -0.9                  71
# 27       1/2/2012 3:00     3.7              -1.5                  69
# ...                ...     ...               ...                 ...
# 8705  12/28/2012 17:00    -8.6             -12.0                  76
# 8753  12/30/2012 17:00   -12.1             -15.8                  74
# 8755  12/30/2012 19:00   -13.4             -16.5                  77
# 8759  12/30/2012 23:00   -12.1             -15.1                  78
# 8760   12/31/2012 0:00   -11.1             -14.4                  77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 23                 30           25.0      99.31            Cloudy
# ...

# %% [markdown]
# 13.what is the mean value for each column against 'Weather condition' According to weather condition

# %%
df.groupby('Weather_Condition').mean()
# Out:
# <ipython-input-86-2fe129e29b33>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Weather_Condition').mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# ...

# %% [markdown]
# 14.What is the min and max value of each column against each 'Weather Condition'

# %%
df.groupby('Weather_Condition').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
df.groupby('Weather_Condition').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %% [markdown]
# 15.Show all the records where weather condition is Fog

# %%
df.groupby('Weather_Condition').get_group('Fog')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 0        1/1/2012 0:00    -1.8              -3.9                  86
# 1        1/1/2012 1:00    -1.8              -3.7                  87
# 4        1/1/2012 4:00    -1.5              -3.3                  88
# 5        1/1/2012 5:00    -1.4              -3.3                  87
# 6        1/1/2012 6:00    -1.5              -3.1                  89
# ...                ...     ...               ...                 ...
# 8716   12/29/2012 4:00   -16.0             -17.2                  90
# 8717   12/29/2012 5:00   -14.8             -15.9                  91
# 8718   12/29/2012 6:00   -13.8             -15.3                  88
# 8719   12/29/2012 7:00   -14.8             -16.4                  88
# 8722  12/29/2012 10:00   -12.0             -13.3                  90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 0                   4            8.0     101.24               Fog
# ...

# %% [markdown]
# 16.Find all the instances where weather is clear and visiblity is above 40

# %%
df['Weather_Condition'] =='Clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather_Condition, Length: 8784, dtype: bool

# %%
df['Visibility_km'] >40
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Visibility_km, Length: 8784, dtype: bool

# %%
df[(df['Weather_Condition'] =='Clear')&(df['Visibility_km'] >40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 351    1/15/2012 15:00   -15.4             -22.8                  53
# 352    1/15/2012 16:00   -15.1             -22.8                  52
# 425    1/18/2012 17:00   -11.3             -18.8                  54
# 440     1/19/2012 8:00   -13.7             -18.4                  68
# 441     1/19/2012 9:00   -12.7             -17.2                  69
# ...                ...     ...               ...                 ...
# 8384   12/15/2012 8:00   -10.7             -15.6                  67
# 8385   12/15/2012 9:00   -10.4             -15.9                  64
# 8389  12/15/2012 13:00    -8.4             -14.7                  60
# 8631  12/25/2012 15:00    -7.1             -13.7                  59
# 8632  12/25/2012 16:00    -7.5             -13.9                  60
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 351                24           48.3     102.71             Clear
# ...

# %% [markdown]
# 17.Find all the instances when :Weather is clear and relative humidity is > 50 or Visiblity is above 40

# %%
df['Weather_Condition']=='Clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather_Condition, Length: 8784, dtype: bool

# %%
df['Relavtive_Humidity']>50
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 8779    True
# 8780    True
# 8781    True
# 8782    True
# 8783    True
# Name: Relavtive_Humidity, Length: 8784, dtype: bool

# %%
df['Visibility_km']>40
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Visibility_km, Length: 8784, dtype: bool

# %%
df[(df['Weather_Condition']=='Clear')&(df['Relavtive_Humidity']>50)|(df['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Relavtive_Humidity  \
# 106     1/5/2012 10:00    -6.0             -10.0                  73
# 107     1/5/2012 11:00    -5.6             -10.2                  70
# 108     1/5/2012 12:00    -4.7              -9.6                  69
# 109     1/5/2012 13:00    -4.4              -9.7                  66
# 110     1/5/2012 14:00    -5.1             -10.7                  65
# ...                ...     ...               ...                 ...
# 8749  12/30/2012 13:00   -12.4             -16.2                  73
# 8750  12/30/2012 14:00   -11.8             -16.1                  70
# 8751  12/30/2012 15:00   -11.3             -15.6                  70
# 8752  12/30/2012 16:00   -11.4             -15.5                  72
# 8756  12/30/2012 20:00   -13.8             -16.5                  80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_Condition
# 106                17           48.3     100.45      Mainly Clear
# ...
